# %%
# !pip install sentence-transformers

# %%
from sentence_transformers import SentenceTransformer

import numpy as np

sbert_model = SentenceTransformer('bert-base-nli-mean-tokens')

# %%
sentences = ["I ate dinner.", 
       "We had a three-course meal.", 
       "Brad came to dinner with us.",
       "He loves fish tacos.",
       "In the end, we all felt like we ate too much.",
       "We all agreed; it was a magnificent evening."]

# %%
# sentence_embeddings = sbert_model.encode(sentences)

# %%
query = sentences[0]
query_vec = sbert_model.encode([query])[0]

# %%
def cosine(u, v):
    return np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))

# %%
for sent in sentences:
    sim = cosine(query_vec, sbert_model.encode([sent])[0])
    print("Sentence = ", sent, "; similarity = ", sim)
# Out:
# Sentence =  I ate dinner. ; similarity =  1.0000001
# Sentence =  We had a three-course meal. ; similarity =  0.63661534
# Sentence =  Brad came to dinner with us. ; similarity =  0.7778474
# Sentence =  He loves fish tacos. ; similarity =  0.496128
# Sentence =  In the end, we all felt like we ate too much. ; similarity =  0.45664704
# Sentence =  We all agreed; it was a magnificent evening. ; similarity =  0.2717442

# %%
query_vec
# Out:
# array([ 1.71653688e-01,  2.26478521e-02,  1.93014610e+00, -2.18605578e-01,
#         3.40926237e-02,  5.23479462e-01, -1.25486863e+00,  9.17776823e-01,
#        -3.36900979e-01, -5.32600343e-01,  3.54304940e-01,  8.74753475e-01,
#         7.92069376e-01,  1.30202755e-01,  3.55943292e-03,  5.88222258e-02,
#         5.33439934e-01, -2.87109047e-01,  1.44994974e-01, -8.17293167e-01,
#        -2.01643333e-02,  1.39118329e-01, -9.96069252e-01,  1.77107498e-01,
#         4.00356911e-02,  4.30927992e-01, -2.58670211e-01,  4.17331129e-01,
#         1.20064116e+00,  9.88089666e-02, -2.55319744e-01, -1.98272895e-02,
#         8.69255602e-01, -8.33961904e-01,  1.74719378e-01, -7.85964668e-01,
#        -1.65306315e-01,  2.84225255e-01, -4.37051296e-01,  6.77007437e-01,
#        -3.97850066e-01,  1.01804554e-01,  7.46633470e-01,  4.15896416e-01,
#        -2.42898390e-02,  2.68644810e-01,  1.04453170e+00,  1.43222332e+00,
# ...

# %%
# !python clean.py --input movies.csv --clean
# Out:
# Cleaning....
# Running RemoveUnnamed cleaner!
# Running GetReleaseYear cleaner!
# Running RunningTimeMins cleaner!

# %%
import pandas as pd

# %%
df = pd.read_csv("movies_filled_cleaned_processed.csv")

# %%
release_date = []

for i, row in df.iterrows():
    if type(row['release_date_filled']) == str:
        release_date.append(row['release_date_filled'])
    else:
        release_date.append(input(f"Enter release date for '{row['Title']}'"))
# Out:
# Enter release date for 'Harry Potter and the Deathly Hallows: Part 2 (2011)'July 11, 2011
# Enter release date for 'Zootopia (2016)'November 4, 2016
# Enter release date for 'Aquaman (2018)'December 21, 2018
# Enter release date for 'The Hobbit: An Unexpected Journey (2012)'December 6, 2012
# Enter release date for 'Harry Potter and the Deathly Hallows: Part 1 (2010)'November 15, 2010
# Enter release date for 'Monsters University (2013)'June 8, 2013
# Enter release date for 'The Hobbit: The Battle of the Five Armies (2014)'December 4, 2014
# Enter release date for 'Justice League (2017)'November 13, 2017
# Enter release date for 'Venom: Let There Be Carnage (2021)'October 1, 2021
# Enter release date for 'Coco (2017)'November 22, 2017
# Enter release date for 'The Amazing Spider-Man 2 (2014)'April 24, 2014
# Enter release date for 'Madagascar (2005)'May 27, 2005
# Enter release date for 'Black Widow (2021)'July 9, 2021
# ...
